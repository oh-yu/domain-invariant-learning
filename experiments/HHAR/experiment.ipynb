# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./data/heterogeneity+activity+recognition/Activity recognition exp/Activity recognition exp/Phones_accelerometer.csv")
df = df[df.User=="a"]
df = df[df.Model=="s3mini"]
df = df[df.Device == "s3mini_2"]
df = df.dropna(how="any")
df = df.reset_index()
gt_to_int_tmp = {"bike": 0, "stairsup": 1, "stairsdown": 2, "stand": 3, "walk": 4}

# %%
df
# Out:
#         index  Index   Arrival_Time  Creation_Time         x         y  \
# 0     1134060      7  1424696697425  6578545201000 -6.206968  1.551443
# 1     1134061      8  1424696697494  6578614092000 -6.218939  1.517924
# 2     1134062      9  1424696697505  6578625437000 -6.226121  1.510741
# 3     1134063     10  1424696697515  6578635440000 -6.240487  1.523909
# 4     1134064     11  1424696697531  6578650993000 -6.228516  1.526304
# ...       ...    ...            ...            ...       ...       ...
# 6350  1142623   8541  1424698501611  6705211595000 -5.358223  0.420182
# 6351  1142624   8542  1424698501626  6705226272000 -4.893748  0.582988
# 6352  1142625   8543  1424698501637  6705237838000 -4.744111  0.687136
# 6353  1142626   8544  1424698501651  6705251600000 -4.499902  0.632069
# 6354  1142627   8545  1424698501666  6705266247000 -4.400543  0.439336
#
#              z User   Model    Device     gt
# 0     7.038953    a  s3mini  s3mini_2  stand
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(df["gt"].apply(lambda x: gt_to_int_tmp[x]))

# %%
plt.figure(figsize=(20,10))
plt.plot(df.x)
plt.plot(df.y)
plt.plot(df.z)
