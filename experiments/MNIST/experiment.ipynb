# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchvision import datasets, transforms
import torchvision
from torchvision.datasets import ImageFolder

# %% [markdown]
# # MNIST

# %%
transform = transforms.ToTensor()
mnist_data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)

# %%
data_loader = torch.utils.data.DataLoader(dataset=mnist_data,
                                          batch_size=64,
                                          shuffle=True)

# %%
c = 0
for img, label in data_loader:
    if label[0] == 8:
        plt.figure()
        plt.imshow(img[0][0], cmap='gray')

        padding = torch.zeros(3, 32, 32)
        padding[:, 2:30, 2:30] = img[0].repeat(3, 1, 1)
        img_replicated = padding.permute(1, 2, 0)
        
        plt.figure()
        plt.imshow(img_replicated, cmap='gray')
        break

# %% [markdown]
# # MNIST-M
# Data is from https://github.com/mashaan14/MNIST-M

# %%
dataset = ImageFolder(root='./data/MNIST-M/training', transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
for images, labels in dataloader:
    if labels[0] == 8:
        print(images.shape)
        print(labels)
        plt.imshow(images[0].permute(1, 2, 0))
        break
# Out:
# torch.Size([32, 3, 32, 32])
# tensor([8, 8, 2, 1, 3, 8, 2, 2, 1, 0, 3, 4, 0, 3, 9, 1, 1, 2, 7, 2, 9, 7, 9, 1,
#         9, 7, 3, 2, 2, 7, 5, 2])

# %% [markdown]
# # SVHN

# %%
svhn_data = torchvision.datasets.SVHN(
    './data/SVHN', 
    split='train', download=True, transform=transform)

data_loader = torch.utils.data.DataLoader(svhn_data, batch_size=4, shuffle=True)
# Out:
# Using downloaded and verified file: ./data/SVHN/train_32x32.mat

# %%
for img, label in data_loader:
    if label[0] == 8:
        print(img.shape)
        print(label)
        plt.figure(figsize=(10, 10))
        plt.imshow(img[0].permute(1, 2, 0))
        # TODO: understand diff between reshape and permute
        break
# Out:
# torch.Size([4, 3, 32, 32])
# tensor([8, 4, 8, 1])
