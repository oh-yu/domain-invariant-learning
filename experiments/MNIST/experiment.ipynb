# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchvision import datasets, transforms
import torchvision

# %% [markdown]
# # MNIST

# %%
transform = transforms.ToTensor()
mnist_data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)

# %%
data_loader = torch.utils.data.DataLoader(dataset=mnist_data,
                                          batch_size=64,
                                          shuffle=True)

# %%
c = 0
for img, label in data_loader:
    # print(img.shape)
    # print(label)
    plt.figure()
    plt.imshow(img[0][0], cmap='gray')

    padding = torch.zeros(3, 32, 32)
    padding[:, 2:30, 2:30] = img[0].repeat(3, 1, 1)
    img_replicated = padding.permute(1, 2, 0)
    
    plt.figure()
    plt.imshow(img_replicated, cmap='gray')
    # print(img_replicated.shape)

    if c == 10:
        break
    c += 1
# Out:
# /home/higuchi-lab/.local/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app

# %% [markdown]
# # MNIST-M
# Data is from https://github.com/mashaan14/MNIST-M

# %%
import numpy as np
from PIL import Image

im = Image.open("./data/MNIST-M/training/3/00000007.png")
im_list = np.asarray(im)
plt.imshow(im_list)

# %% [markdown]
# # SVHN

# %%
svhn_data = torchvision.datasets.SVHN(
    './data/SVHN', 
    split='train', download=True, transform=transform)

data_loader = torch.utils.data.DataLoader(svhn_data, batch_size=4, shuffle=True)
# Out:
# Using downloaded and verified file: ./data/SVHN/train_32x32.mat

# %%
for img, label in data_loader:
    print(img.shape)
    print(label)
    plt.figure(figsize=(10, 10))
    plt.imshow(img[3].permute(1, 2, 0))
    # TODO: understand diff between reshape and permute
    break
# Out:
# torch.Size([4, 3, 32, 32])
# tensor([3, 2, 3, 1])
